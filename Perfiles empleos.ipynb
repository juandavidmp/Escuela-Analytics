# %%
perfiles_empleo = {
    "Analista de datos1":{"Empresa":"Kin+Carta",
                         "Experiencia laboral":False,
                         "Requerimientos min":["Experiencia en la industria o un pregrado en estudios cuantitativos incluyendo matemáticas, estadística o ciencia de datos.","Competencia en lenguajes programáticos como SQL, Python, R."],
                         "Requerimientos pref":["Competencias en Tableau o Power BI, o en R (ggplot2),  Python (matplotlib/seaborn/bokeh) o Javascript D3.","Dominio de secuencias de comandos en entorno UNIX.","Competencia en entornos y herramientas de big data como Spark, Hive, Impala, Pig, etc.","Competencia con software de canalización de datos como Airflow, Luigi o Prefect.","Experiencia con bibliotecas estadísticas y de aprendizaje automático junto con la capacidad de aplicarlas adecuadamente a problemas comerciales.","Competencia en marcos y pilas de desarrollo de aplicaciones web front-end y back-end (Javascript, HTML, CSS, React/Vue/AngularJS)."],
                         "Descripción empleo":[""]
                         },
    "Analista de datos2":{"Empresa":"Rappi",
                         "Experiencia laboral":True,
                         "Requerimientos min":["Experiencia de mínimo 1 año.","Licenciatura en informática, matemáticas, economista, gestión de datos, marketing, estadística, física, un campo relacionado.","Experiencia en análisis de datos, elaboración de informes, investigación de mercado, segmentación y modelado de datos","Fuerte trabajo en equipo y orientación al servicio al cliente","Sólidos tableros de construcción de conocimiento en Power BI o similar","Fuertes habilidades de SQL","Alto dominio en Microsoft Excel","Experiencia o conocimiento en finanzas"],
                         "Requerimientos pref":["Experiencia en programación con lenguaje Python.","Fluidez en inglés o portugués."],
                         "Descripción empleo":["Use datos y análisis para enriquecer los informes con información más poderosa y mejore los pronósticos con recomendaciones basadas en datos","Aproveche las fuentes de datos nuevas y existentes para desarrollar paneles y visualizaciones prácticas, perspicaces y dinámicas","Cree, mantenga y optimice informes, incluidas sentencias SQL, vistas, funciones y procesadores almacenados"]
                         },
    "Analista de crédito1":{"Empresa":"Comdata España & Latam",
                           "Experiencia laboral":True,
                           "Requerimientos min":["Experiencia de mínimo de 1 AÑO en monitoreo transaccional y/o en monitoreo del sistema de administración de riesgo operativo, bloqueo de tarjetas crédito o débito.","Formación académica: técnico, tecnólogo o estudiantes universitarios en áreas administrativas, ingenierías o a fines.","Con conocimientos en AS400, BBM,BRM Y/O MONITOR PLUS."],
                           "Requerimientos pref":[""],
                           "Descripción empleo":[""]
                           },
    "Analista de crédito2":{"Empresa":"Magneto",
                           "Experiencia laboral":True,
                           "Requerimientos min":["Profesional de carreras administrativas, ciencias de la información, ingenierías o financieras.","Experiencia mínima de 2 años en el sector financiero relacionada con el conocimiento de la normatividad vigente con respecto al Riesgo de Crédito.","Conocimientos en políticas y procedimientos en la originación de Crédito y metodología crediticia.","Conocimientos en legislación vigente aplicable en administración de riesgos financieros.","Excel avanzado con funcionalidad de macros (VBA) y Power BI.","SQL o Access Intermedio(deseable)","Python con dominio en tecnologías vinculadas a Machine Learning y Big Data."],
                           "Requerimientos pref":["R (deseable) para desarrollo de modelos."],
                           "Descripción empleo":["Apoyo constante a la Dirección de Riesgo frente al cumplimiento de la normatividad externa e interna sobre el Riesgo de Crédito mediante el análisis, creación de indicadores y modelos que permitan tomar decisiones oportunas para el buen y sano crecimiento de la cartera y por ende de la organización."]
                           },
    "Analista financiero1":{"Empresa":"Falabella Retail S.A.",
                           "Experiencia laboral":True,
                           "Requerimientos min":["Experiencia de mínimo 1 año en análisis financiero (evaluación, proyección y revisión).","Profesional en Finanzas, Ingeniería Industrial, Economía, Administración de Empresas o afines.","Excelente habilidades matemáticas y analíticas; conocimientos contables, conocimientos en elaboración y análisis de estados financieros y proyecciones financieras.","Manejo avanzado de Excel.","Excelente comunicación oral y escrita."],
                           "Requerimientos pref":[""],
                           "Descripción empleo":["Esta persona será responsable de apoyar la realización de informes de gestión financiera mensuales (resultados, explicaciones e indicadores), de acuerdo a los lineamientos y estrategia corporativa, con el fin de apoyar la consolidación del presupuesto y control de las áreas de la compañía, así mismo, apoyo en la generación de información y análisis de gestión de ingresos, costos y gastos."]
                           },
    "Analista financiero2":{"Empresa":"Wartsila",
                            "Experiencia laboral":True,
                            "Requerimientos min":["Licenciatura en Negocios, Finanzas o Economía, u otro campo que apoye la tarea","Una comprensión general de los sistemas de energía, las plantas de energía y el modelado de sistemas de energía.","Excelentes habilidades analíticas, una buena comprensión del análisis financiero, así como habilidades avanzadas en herramientas de Excel.","Fluidez en inglés y español.",""],
                            "Requerimientos pref":[""],
                            "Descripción empleo":["Como analista financiero y de mercado, apoyará a la organización de ventas con: 1. Estudios de mercado, 2. Viabilidad del proyecto, 3. Estudios de comparación de tecnología, 4. Almacenamiento de energía renovable: estudios híbridos, 5. Interacciones de Clientes, Consultores y Partes Interesadas en Energía."]
                           },
    "Analista financiero3":{"Empresa":"Rappi",
                            "Experiencia laboral":True,
                            "Requerimientos min":["Mínimo un año de experiencia","Profesional en administración de empresas, ingeniería industrial o carreras afines)","Buen manejo de Excel y Power Point","Manejo de bases de datos","Buenas habilidades de comunicación, capacidad de presentar en reuniones y juntas directivas","Nivel de ingles avanzado"],
                            "Requerimientos pref":["Experiencia en Retail","SQL","Experiencia en compañías de tecnología"],
                            "Descripción empleo":["Revisión y análisis de cifras financieras (FP&A), planeación y control de gastos de un país, revisión de EEFF para coordinar con 3ro contable cifras financieras y acompañamiento en procesos de gestión de la compañía para llevarla a punto de equilibrio."]
                           },
    "Analista financiero4":{"Empresa":"Nokia",
                            "Experiencia laboral":True,
                            "Requerimientos min":["Mínimo 3 años de experiencia","Habilidades de informes y análisis financieros","Experiencia con los siguientes procesos y herramientas de CFO: conocimiento de ERP (SAP)","Muy buen manejo de MS Office Excel","Manejo de Power BI","Competente en inglés"],
                            "Requerimientos pref":["Manejo de Power Pivot"],
                            "Descripción empleo":[""]
                            },
    "Practicante riesgo1":{"Empresa":"GM Financial",
                          "Experiencia laboral":False,
                          "Requerimientos min":["Estudiante de alguna de las siguientes carreras: Ingeniería Industrial, Ingeniería Financiera, Finanzas, Actuario, Economía, Administración de Empresas, Estadística, Computación o similar.","Amplias habilidades informáticas, principalmente las herramientas de Microsoft Office: Excel y PowerPoint.","Dominio del español y nivel intermedio de inglés."],
                          "Requerimientos pref":["Si tiene conocimiento en al menos uno de los siguientes softwares será una ventaja: VBA, SAS, COGNOS, SQL, Python, R. Power BI o herramientas similares."],
                          "Descripción empleo":["El empleado será responsable de la identificación, medición, seguimiento y control de la exposición al riesgo de crédito y/o liquidez, asegurando el cumplimiento de la regulación local y políticas corporativas, con el fin de realizar una adecuada gestión de los riesgos y agregar valor a la Compañía a través de los diferentes informes, análisis y otros entregables."]
                          },
    "Trader1":{"Empresa":"Cobblestone Energy",
               "Experiencia laboral":False,
               "Requerimientos min":["Excelentes habilidades de razonamiento numérico y lógico.","Un historial de excelencia, tanto dentro como fuera de lo académico.","Al menos honores superiores de segunda clase en la universidad; y percentil 90+ en matemáticas de nivel secundario.","Pasión, resiliencia e integridad."],
               "Requerimientos pref":[""],
               "Descripción empleo":["Como trader junior, estará al frente de nuestro negocio. Trabajará con nuestro equipo comercial para hacer uso de nuestro análisis y tecnología para ejecutar operaciones rentables en tiempo real."]
              },
    "Trader2":{"Empresa":"Porvenir Pensiones y Cesantías",
               "Experiencia laboral":True,
               "Requerimientos min":["Manejo de Excel avanzado.","Manejo de Python nivel intermedio/avanzado.","Nivel de inglés: Avanzado.","Capacidad de Análisis cuantitativo.","Manejo de base de datos."],
               "Requerimientos pref":[""],
               "Descripción empleo":["Administración del portafolio de Renta Variable extranjera y local para pensiones obligatorias y cesantías.","Generación de propuestas tácticas y estructurales.","Elaboración de modelos cuantitativos para la toma de decisiones del portafolio de renta variable internacional."]
              },
    "Trader3":{"Empresa":"Banco de Bogotá",
               "Experiencia laboral":True,
               "Requerimientos min":["Profesionales en Ingeniería Industrial, Administración de Empresas, Economía o Finanzas.","Experiencia de mínimo 2 años.","Certificación AMV.","Manejo de Excel avanzado.","Inglés intermedio.","Conocimiento de manejo de flujo de caja y macroeconomía."],
               "Requerimientos pref":[""],
               "Descripción empleo":["El Trader de liquidez moneda legal es la persona encargada en administrar la liquidez en COP, y quien vela por el cumplimiento del encaje bancario, gestión de excedentes o faltantes de liquidez en la tesorería del Banco de Bogotá."]
              },
    "Trader4":{"Empresa":"Falabella",
               "Experiencia laboral":True,
               "Requerimientos min":["Mínimo 2 años de experiencia","Profesional en carreras administrativas con énfasis en Finanzas","Certificado en AMV en Operador Básico, Renta Fija y Derivados","Análisis técnico y fundamental de mercados","Swaps de tasas de interés"],
               "Requerimientos pref":[""],
               "Descripción empleo":["Proponer y ejecutar estrategias de trading para el portafolio de renta fija del banco, tanto en deuda pública como deuda privada, garantizando el cumplimiento de los límites normativos y corporativos establecidos, con el fin de optimizar la rentabilidad de las inversiones y generar utilidad de trading."]
              },
    "Trader5":{"Empresa":"Itaú",
               "Experiencia laboral":False,
               "Requerimientos min":["Profesional en Economía, Administración de Empresas, Ingeniería Industrial, Negocios Internacionales, Comercio Exterior o afines","Certificaciones de AMV en operador básico y divisas"],
               "Requerimientos pref":[""],
               "Descripción empleo":["Comercializar la góndola de productos y servicios de la Tesorería con los clientes del segmento asignado, logrando satisfacer sus necesidades e intereses, promoviendo la construcción de relaciones sostenibles, así como garantizar la adecuada rentabilidad para el banco y el cumplimiento de los presupuestos."]
              },
    "Asistente de operaciones":{"Empresa":"Bancolombia (Miami)",
                                 "Experiencia laboral":True,
                                 "Requerimientos min":["Experiencia de mínimo 3 años en temas relacionados con el mercado de capitales en EEUU.", "Pregrado en finanzas, contabilidad o carreras a fines.", "Conocimiento de pershing y las herramientas que tiene este aplicativo.", "Dealer y un Register Investment Adviser en Estados Unidos (contrato de comisión, administración de portafolios de terceros).", "Bilingüe (Español e Inglés).", 
                                                       "Residencia de trabajo en Miami."],
                                 "Requerimientos pref":[""],
                                 "Descripción empleo":["Participarás con el Head of Operations en definiciones estratégicas relacionadas con políticas, cambios organizacionales, proyectos, objetivos, presupuestos y su correspondiente seguimiento, que garantice excelentes resultados en la entidad.", "Registrarás los giros y traslados de títulos de clientes de manera exitosa buscando una experiencia superior del cliente.", "Registrarás las operaciones de renta fija de contrapartes y hacer gestión para su debido cumplimiento en el día establecido (T+n)",
                                                       "Realizarás seguimiento a los planes de acción derivados de Auditoría Interna y Revisoría Fiscal y velar por que estos se cierren de manera oportuna.","Serás responsable de la buena administración de los pagos a proveedores de la entidad","Recibirás y gestionarás las solicitudes de transferencias y traslados de títulos.", "Atenderás solicitudes del equipo comercial y clientes frente a los portafolios de estos."]
                                },
    "Profesional riesgo tasas de interés":{"Empresa":"Davivienda",
                                           "Experiencia laboral":False,
                                           "Requerimientos min":["Profesional en Ingeniería Industrial, Economía, Finanzas, Administración de Empresas o afines.","Nivel avanzado en Office (Word, Excel, PowerPoint).","Conocimientos en lenguajes de programación y manejo de bases de datos.","Conocimientos en Python y SQL.","Deseable manejo de proveedores de información financiera tipo Bloomberg o Reuters.","Nivel de inglés B2"],
                                           "Requerimientos pref":["Énfasis en temas relacionados con el cargo incluyendo finanzas, gestión de riesgos, estrategia, gestión bancaria, modelamiento financiero, estadística o ingenierías."],
                                           "Descripción empleo":["Apoyar el proceso de identificación, medición, control y monitoreo del Riesgo de Tasa de Interés, basado en herramientas construidas a partir de Visual Basic, Python y SQL.","Hacer seguimiento a la estructura del balance y evaluar el riesgo ante los descalces en plazos y tasas de interés.","Participar dentro del proceso de definición de Tasas de Colocación y Captación, dentro de las prácticas de Transferencia de Precios (FTP).","Participar en el diseño de políticas y procedimientos que permitan identificar y corregir desviaciones en la estructura del balance, de cara al perfil de riesgo del banco."]
                                          },
    "Especialista de Marketing & Growth DaviPlata":{"Empresa":"Davivienda",
                                                    "Experiencia laboral":True,
                                                    "Requerimientos min":["Experiencia mínima de 2 años en planeación, ejecución de marketing, estructuración de campañas enredes sociales y manejo de presupuesto en campañas.", "Profesional en Ingeniería, Finanzas, Administración de empresas o marketing.", "Manejo enfocado en bases de datos SQL.","Manejo de herramientas de visualización de reportes Power BI, tableau y Data Studio.",""],
                                                    "Requerimientos pref":["Especialización en data scientist.", "Deseable experiencia en herramientas para envió de Emails, SMS, Push e In Apps."],
                                                    "Descripción empleo":["Planeación estratégica con la línea de negocio de Oferta Financiera y el área de Marketing.","Crear y ejecutar el plan de comunicaciones masivas y dirigidas.","Actualizar y mantener las bases de datos para comunicación de campañas masivas y Journeys."]
                                                   },
    "Administrador Negocios Fiducia Inmobiliaria T.F.":{"Empresa":"Davivienda",
                                                        "Experiencia laboral":True,
                                                        "Requerimientos min":["Profesionales en economía, finanzas, ingeniería industrial, administración de empresas o carreras afines.","Mínimo 2 años de experiencia administrando negocios fiduciarios, indispensable tipología inmobiliaria"],
                                                        "Requerimientos pref":[""],
                                                        "Descripción empleo":["Lectura y análisis del contrato y sus anexos de los negocios a su cargo","Verificar en el certificado el traspaso del lote a la fiduciaria y la hipoteca a la entidad financiera, y verificar que no tenga ninguna afectación en el dominio.","Revisar y solicitar los ajustes necesarios para la depuración de partidas conciliatorias y ajustes a la información de terceros registrada en los Estados Financieros."]
                                                       },
    "Especialista en finanzas de la transición":{"Empresa":"Banco de Bogotá",
                                                 "Experiencia laboral":True,
                                                 "Requerimientos min":["Experiencia de 3 a 5 años en temas de sostenibilidad en los sectores de Energía y Oil&Gas, incluyendo estrategias e iniciativas ambientales y climáticas.", "Profesional en ingeniería, economía, administración o carreras afines.","Experiencia en estructuración y análisis financiero de proyectos e iniciativas con impacto ambiental y climático","Conocimiento de iniciativas regulatorias y estándares nacionales e internacionales alrededor de cambio climático, Net Zero y finanzas sostenibles.","Entendimiento de productos y estrategias de banca corporativa.","Nivel intermedio/alto de inglés."],
                                                 "Requerimientos pref":["Maestría o especialización en campos relacionados con sostenibilidad, ciencias ambientales, ciencias del clima o energía", "Experiencia específica en Net Zero y programas de descarbonización y transición climática","Experiencia en el desarrollo de estrategias corporativas y comerciales, con participación de múltiples stakeholders internos y externos"],
                                                 "Descripción empleo":["Identificación de oportunidades comerciales de financiamiento de la transición en sectores clave (iniciando con Energía y Oil&Gas), incluyendo la estimación del tamaño de la oportunidad y la colaboración con RMs para promover la colocación de créditos sostenibles."]
                                                 },
    "Analista economía circular":{"Empresa":"Postobón",
                                  "Experiencia laboral":True,
                                  "Requerimientos min":["Experiencia mínima de 4 años en gestión de proyectos en servicio públicos de aseo, proyectos de aprovechamiento de residuos, proyectos sociales con población vulnerable, proyectos de prestación de servicios logísticos.","Profesional en Administración, Económicas, Ambienta, Ingeniería o afines","Conocimientos en Excel avanzado, normativa de responsabilidad extendida, logística, costeo de proyectos, ciclo de vida de materiales."],
                                  "Requerimientos pref":[""],
                                  "Descripción empleo":["Coordinar y realizar seguimiento a las alianzas entre los gestores de material aprovechables pos consumo y otros actores con los proveedores de materiales de envases y empaques de las empresas para asegurar la estabilidad y sostenibilidad de la cadena de aprovisionamiento de materia prima para los envases y empaques de la compañía."]
                                  },
    "Analista crédito y cartera":{"Empresa":"Postobón",
                                  "Experiencia laboral":True,
                                  "Requerimientos min":["3 años de experiencia en Gestión de Cartera.","Formación en Estadística, Ciencias Administrativas, Económicas y Financieras o afines."],
                                  "Requerimientos pref":[""],
                                  "Descripción empleo":["Gestionar la cartera de clientes de canal moderno y clientes especiales que estén en instancias prejurídicas, con el fin de recuperar el valor máximo posible de cartera.","Preparar y presentar informes de los indicadores de gestión concernientes a cartera, con el fin de generar alertas tempranas sobre posibles riesgos.","Proponer e implementar estrategias de cobranza en todas sus etapas (visitas, cartas, mensajes de texto), garantizando que se minimicen los riesgos asociados."]
                                  },
    "Riesgo de Liquidez y Límites Legales de Crédito (Pasantía)":{"Empresa":"JP Morgan Chase & Co.",
                                                       "Experiencia laboral":False,
                                                       "Requerimientos min":["Estudiante de carreras como Administración de Empresas, Economía, Ingeniería Industrial y otros relacionados","Conocimientos en Excel a nivel intermedio.","Atención al detalle y gran capacidad de análisis.","Nivel intermedio de inglés","Alto sentido de la responsabilidad."],
                                                       "Requerimientos pref":[""],
                                                       "Descripción empleo":["Asistir al equipo responsable de capital riesgo, liquidez y límites legales de crédito en la identificación, medición, seguimiento y control de los diferentes límites y alertas en diversas funciones"]
                                                       },
    "Banca Corporativa Global (Pasantía)":{"Empresa":"JP Morgan Chase & Co.",
                                           "Experiencia laboral":False,
                                           "Requerimientos min":["Interés en finanzas corporativas y análisis financiero.","Fuertes habilidades analiticas","Excelentes habilidades de comunicación verbal y escrita en inglés y español.","Mentalidad comercial: capaz de comunicarse con clientes internos y externos.","Conocimiento del paquete MS Office"],
                                           "Requerimientos pref":[""],
                                           "Descripción empleo":["Apoyar las actividades de los banqueros de GCB, incluyendo: (a) análisis financiero; (b) modelado y pronóstico; y (c) coordinación con los especialistas de producto de J.P. Morgan","Comprender la dinámica empresarial de las industrias y sectores, analizando los requisitos financieros de las corporaciones.","Desarrollo de planes de negocios y preparación de libros de presentación para clientes actuales y potenciales, apoyando la conversión del análisis del cliente en soluciones financieras concretas."]
                                           },
    "Analista de tiempo completo de banca de inversión - Latinoamérica":{"Empresa":"JP Morgan Chase & Co.",
                                                                         "Experiencia laboral":False,
                                                                         "Requerimientos min":["Profesional en finanzas, economía, ingeniería o negocios","Attend college/university in the U.S.","Excelentes habilidades analíticas, cuantitativas y de comunicación.","Excelente liderazgo y habilidades de colaboración.","La fluidez en Inglés","Conocimientos de Excel, PowerPoint y Word"],
                                                                         "Requerimientos pref":["Experiencia en finanzas corporativas o economía","Fluidez en español y/o portugués."],
                                                                         "Descripción empleo":["Trabajando en procesos de fusiones y adquisiciones y transacciones de mercado de capitales","Realización de análisis de valoración","Creación de modelos financieros detallados y ejecución de transacciones desde el lanzamiento hasta el cierre","Análisis de datos de mercado, creación de modelos financieros detallados y preparación de presentaciones para clientes."]
                                                                         },
    "Ventas Comerciales (Pasantía)":{"Empresa":"JP Morgan Chase & Co.",
                                     "Experiencia laboral":False,
                                     "Requerimientos min":["Estudiantes de Negocios, Finanzas, Economía, Ingeniería y áreas afines","Conocimiento del paquete MS Office","Excelentes habilidades organizativas y de resolución de problemas.","Excelentes habilidades verbales y escritas en español e inglés."],
                                     "Requerimientos pref":["Habilidades comunicativas en portugués"],
                                     "Descripción empleo":["Apoyo a los Oficiales de Ventas en las demandas diarias","Mantener la canalización actualizada, lo que incluye trabajar en la entrada de los sistemas de canalización","Trabajar en presentaciones de Powerpoint para clientes y propuestas de precios internos.","Asóciese con diferentes equipos en Producto, Legal, Operaciones, Banca e Implementación en la ejecución de acuerdos"]
                                     },
    "Analista de Riesgo de Capital y Liquidez":{"Empresa":"JP Morgan Chase & Co.",
                                                "Experiencia laboral":False,
                                                "Requerimientos min":["Profesional en economía, administración de empresas, finanzas, ingeniería industrial o áreas afines.","Nivel avanzado de Excel con conocimientos de lenguajes de programación o Visual Basic.","Alta capacidad de interpretación y análisis de datos.","Conocimientos de matemáticas financieras."],
                                                "Requerimientos pref":[""],
                                                "Descripción empleo":["Su objetivo principal es lograr un conocimiento completo de los indicadores, límites, controles, alertas y en general toda la información que genera el área para participar activamente en la elaboración de informes internos y regulatorios, apoyando la medición, seguimiento y control."]
                                                },
    "Ventas Tesorería FI Colombia (Pasantía)":{"Empresa":"JP Morgan Chase & Co.",
                                               "Experiencia laboral":False,
                                               "Requerimientos min":["Análisis: excelentes habilidades analíticas para obtener datos que se utilizarán en el análisis de clientes, revisando las tendencias de ingresos y rentabilidad.","Pensamiento estratégico: capacidad para comprender los objetivos estratégicos del negocio de Servicios de Tesorería y traducirlos en formas de representar los resultados.","Gestión de proyectos: gestione múltiples proyectos simultáneamente manteniéndolos en marcha.","Habilidades interpersonales: excelentes habilidades interpersonales y la capacidad de trabajar de forma independiente una vez que se explican las metas y objetivos del proyecto.","Comunicación: habilidades excepcionales de escritura y comunicación verbal, incluida la capacidad de transmitir ideas complejas de manera simple a diferentes audiencias."],
                                               "Requerimientos pref":[""],
                                               "Descripción empleo":["Conocer los productos de Servicios de Tesorería, con las principales funcionalidades involucradas en la operativa diaria del cliente, pudiendo realizar presentaciones avanzadas, análisis con números, informes, gráficos y redacción integral en las principales aplicaciones de MS Office.","Operar en plataformas de Servicios de Tesorería para obtener información confiable y rápida, apoyando al Gerente de Ventas de Tesorería y al Asociado de Ventas en las necesidades diarias."]
                                               },
    "Inversiones internacionales":{"Empresa":"Banco de la República de Colombia",
                                   "Experiencia laboral":False,
                                   "Requerimientos min":["Profesionales en Administración de empresas, Finanzas, Relaciones Internacionales Ingeniería industrial o Economía","Nivel de inglés B2","Promedio académico acumulado pregrado no inferior a 4.0", "Conocimientos en: Macroeconomía, política monetaria, riesgos financieros, regulación del sistema financiero, mercados, deuda pública, finanzas, matemáticas, estadística, etc."],
                                   "Requerimientos pref":[""],
                                   "Descripción empleo":["Participar en la planeación y ejecutar las operaciones de inversión autorizadas. Hacer seguimiento a los principales mercados financieros internacionales y participar en la proposición y administración de posiciones activas para los portafolios no indexados en los mercados asignados."]
                                   },
    "Analista de Riesgo de Mercado y Liquidez":{"Empresa":"ExcelCredit",
                                                "Experiencia laboral":True,
                                                "Requerimientos min":["Mínimo 1 año de experiencia en aspectos relacionados a este rol.","Profesional de carreras administrativas, económicas o financieras.","Conocimientos sólidos en cálculo de IRL y VaR.",""],
                                                "Requerimientos pref":[""],
                                                "Descripción empleo":["Garantizar la identificación, medición, control y monitoreo de procesos con el fin de evitar pérdidas financieras que se puedan derivar de la exposición a los riesgos de mercado y liquidez"]
                                                },
    "Analista de inversión":{"Empresa":"Finance in Motion",
                             "Experiencia laboral":False,
                             "Requerimientos min":["Profesional en en ingeniería industrial, economía, administración de empresas, finanzas o carrera afín","Suficiente experiencia relevante en inversiones, finanzas, banca de inversión o antecedentes similares","Fuertes habilidades analíticas","Capacidad demostrada para navegar grandes conjuntos de datos para identificar puntos clave","Habilidades excepcionales de comunicación comercial verbal y escrita en inglés."],
                             "Requerimientos pref":[""],
                             "Descripción empleo":["Análisis financiero (construcción de modelos financieros, flujos de caja y análisis de sensibilidad empresarial)","Apoyar los esfuerzos de diligencia debida, incluido el análisis de la industria y la redacción de memorandos de inversión.","Apoyar la gestión de la cartera (seguimiento del impacto, métricas financieras y operativas y preparación de informes de rendimiento)"]
                             },
    "Analista de crédito3":{"Empresa":"Mibanco Colombia",
                            "Experiencia laboral":True,
                            "Requerimientos min":["Experiencia mínima de 2 años en el sector financiero relacionada con el conocimiento de la normatividad vigente con respecto al Riesgo de Crédito","Profesional de carreras administrativas, ciencias de la información, ingenierías o financieras."],
                            "Requerimientos pref":[""],
                            "Descripción empleo":[""]
                            },
    "Analista asociado de procesamiento comercial y de efectivo":{"Empresa":"Citi",
                                                                  "Experiencia laboral":True,
                                                                  "Requerimientos min":["3 a 5 años de experiencia en un campo relevante con al menos 2-3 años de experiencia en operaciones de servicios comerciales.","Comprensión completa de las normas y reglamentos que se aplican a los LC -ISP98, UCP600, ISBP","Dominio de nivel experto en Windows, MS Project y MS Office Suite","Habilidades demostradas de gestión de proyectos.","Fluido en inglés"],
                                                                  "Requerimientos pref":["CDCS preferido.", "Fluidez en portugués"],
                                                                  "Descripción empleo":["Emitir, asesorar y confirmar Cartas de Crédito Documentarias y enmiendas (Imp, Exp, Stand by y Garantías) a los instrumentos de crédito originales, en línea con el plazo y las expectativas de precisión establecidas por los Procedimientos de CTI, para garantizar el cumplimiento de todas las normas locales e internacionales aplicables. regulaciones","Examinar las cartas de crédito de importación, exportación y standby en busca de posibles problemas de boicot, informa L/C","Apoyar el procesamiento transaccional para los respectivos productos de Carta de Crédito, revisar los documentos de Carta de Crédito para determinar el cumplimiento de las normas y estándares internacionales, de EE. UU. Latam y/o mexicanos"]
                                                                  },
}

# %%
len(perfiles_empleo)
# Out:
# 32
